# %%
# !pip install ..
# Out:
# Processing /Users/Guille/code/GuillermoIzquierdo/GANs
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from GANs==0.0.0) (1.5.2)
# Requirement already satisfied: numpy in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from GANs==0.0.0) (1.23.5)
# Requirement already satisfied: tensorflow in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from GANs==0.0.0) (2.11.0)
# Requirement already satisfied: pillow in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from GANs==0.0.0) (9.3.0)
# Requirement already satisfied: opencv-python in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from GANs==0.0.0) (4.6.0.66)
# Requirement already satisfied: ipython in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from GANs==0.0.0) (8.7.0)
# Requirement already satisfied: matplotlib in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from GANs==0.0.0) (3.6.2)
# Requirement already satisfied: cairocffi in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from GANs==0.0.0) (1.4.0)
# Requirement already satisfied: cffi>=1.1.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from cairocffi->GANs==0.0.0) (1.15.1)
# Requirement already satisfied: appnope in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from ipython->GANs==0.0.0) (0.1.3)
# Requirement already satisfied: pickleshare in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from ipython->GANs==0.0.0) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from ipython->GANs==0.0.0) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from ipython->GANs==0.0.0) (0.1.6)
# Requirement already satisfied: decorator in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from ipython->GANs==0.0.0) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from ipython->GANs==0.0.0) (5.7.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from ipython->GANs==0.0.0) (3.0.36)
# Requirement already satisfied: jedi>=0.16 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from ipython->GANs==0.0.0) (0.18.2)
# Requirement already satisfied: pygments>=2.4.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from ipython->GANs==0.0.0) (2.13.0)
# Requirement already satisfied: backcall in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from ipython->GANs==0.0.0) (0.2.0)
# Requirement already satisfied: stack-data in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from ipython->GANs==0.0.0) (0.6.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from matplotlib->GANs==0.0.0) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from matplotlib->GANs==0.0.0) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from matplotlib->GANs==0.0.0) (22.0)
# Requirement already satisfied: cycler>=0.10 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from matplotlib->GANs==0.0.0) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from matplotlib->GANs==0.0.0) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from matplotlib->GANs==0.0.0) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from matplotlib->GANs==0.0.0) (1.0.6)
# Requirement already satisfied: pytz>=2020.1 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from pandas->GANs==0.0.0) (2022.6)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (22.12.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (1.16.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (3.19.6)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (1.3.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (0.28.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (4.4.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (1.51.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (2.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (14.0.6)
# Requirement already satisfied: setuptools in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (56.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (2.1.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (1.14.1)
# Requirement already satisfied: h5py>=2.9.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorflow->GANs==0.0.0) (3.7.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow->GANs==0.0.0) (0.38.4)
# Requirement already satisfied: pycparser in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from cffi>=1.1.0->cairocffi->GANs==0.0.0) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from jedi>=0.16->ipython->GANs==0.0.0) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from pexpect>4.3->ipython->GANs==0.0.0) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython->GANs==0.0.0) (0.2.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (2.15.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (2.2.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (1.8.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from stack-data->ipython->GANs==0.0.0) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from stack-data->ipython->GANs==0.0.0) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from stack-data->ipython->GANs==0.0.0) (1.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (5.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/Guille/.pyenv/versions/3.8.12/envs/GANs/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->GANs==0.0.0) (3.2.2)
# Building wheels for collected packages: GANs
#   Building wheel for GANs (setup.py) ... done
#   Created wheel for GANs: filename=GANs-0.0.0-py3-none-any.whl size=6788 sha256=0233c2703e8b83adff5222340b8727503b93a193dc8804b93b22824b79c38164
#   Stored in directory: /private/var/folders/0w/yx9msd751_v0j2zv7hy8zp1w0000gp/T/pip-ephem-wheel-cache-nk4va5mz/wheels/bf/a9/d6/1bea89027c0d47b5ec122bce59f312b9f3304766c2b18e0c43
# Successfully built GANs
# Installing collected packages: GANs
#   Attempting uninstall: GANs
#     Found existing installation: GANs 0.0.0
#     Uninstalling GANs-0.0.0:
#       Successfully uninstalled GANs-0.0.0
# Successfully installed GANs-0.0.0

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import cv2
from PIL import Image
from IPython.display import clear_output
import os
import matplotlib.pyplot as plt

# %%
from gans.utils.params import *
from gans.training.train import *
from gans.models.union import *
# Out:
# 2022-12-12 16:35:29.307318: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
generator_celeb, discriminator_celeb, gan_celeb = construct_models(verbose=True)
# Out:
# 2022-12-12 16:35:41.320827: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 100)]             0
#
#  dense_1 (Dense)             (None, 2048)              206848
#
#  batch_normalization_8 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  reshape (Reshape)           (None, 4, 4, 128)         0
#
#  conv2d_transpose (Conv2DTra  (None, 8, 8, 64)         204864
#  nspose)
#
#  batch_normalization_9 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 8, 8, 64)          0
#
#  conv2d_transpose_1 (Conv2DT  (None, 16, 16, 32)       51232
#  ranspose)
#
#  batch_normalization_10 (Bat  (None, 16, 16, 32)       128
#  chNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 16, 16, 32)        0
#
#  conv2d_transpose_2 (Conv2DT  (None, 32, 32, 16)       12816
#  ranspose)
#
#  batch_normalization_11 (Bat  (None, 32, 32, 16)       64
#  chNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 32, 32, 16)        0
#
#  conv2d_transpose_3 (Conv2DT  (None, 64, 64, 16)       6416
#  ranspose)
#
#  batch_normalization_12 (Bat  (None, 64, 64, 16)       64
#  chNormalization)
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 64, 64, 16)        0
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 3)         1203
#
# =================================================================
# Total params: 492,083
# Trainable params: 487,731
# Non-trainable params: 4,352
# _________________________________________________________________
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d (Conv2D)             (None, 64, 64, 16)        1216
#
#  batch_normalization (BatchN  (None, 64, 64, 16)       64
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 16)        6416
#
#  batch_normalization_1 (Batc  (None, 32, 32, 16)       64
#  hNormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 32, 32, 16)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        12832
#
#  batch_normalization_2 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 32)        25632
#
#  batch_normalization_3 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 16, 16, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        51264
#
#  batch_normalization_4 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 64)          102464
#
#  batch_normalization_5 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 8, 8, 64)          0
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 128)         204928
#
#  batch_normalization_6 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 128)         409728
#
#  batch_normalization_7 (Batc  (None, 4, 4, 128)        512
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 4, 4, 128)         0
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 816,529
# Trainable params: 0
# Non-trainable params: 816,529
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_1 (Functional)        (None, 64, 64, 3)         492083
#
#  model (Functional)          (None, 1)                 816529
#
# =================================================================
# Total params: 1,308,612
# Trainable params: 487,731
# Non-trainable params: 820,881
# _________________________________________________________________

# %%
generator_celeb, discriminator_celeb, gan_celeb = run_training(generator_celeb, 
                                                               discriminator_celeb, 
                                                               gan_celeb, 
                                                               num_epochs=500, 
                                                               df=df_celeb)
# Out:
# Epoch 65
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 287ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 1s 636ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 976ms/step
# 1/1 [==============================] - 1s 732ms/step
# 1/1 [==============================] - 1s 929ms/step
# 1/1 [==============================] - 1s 628ms/step
# 1/1 [==============================] - 1s 684ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 800ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 893ms/step
# 1/1 [==============================] - 0s 441ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 289ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 336ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 340ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 382ms/step
# 1/1 [==============================] - 0s 456ms/step
# 1/1 [==============================] - 0s 460ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 453ms/step
# 1/1 [==============================] - 1s 975ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 458ms/step
# 1/1 [==============================] - 0s 359ms/step
# 1/1 [==============================] - 0s 277ms/step
# 1/1 [==============================] - 0s 279ms/step
# 1/1 [==============================] - 0s 251ms/step
